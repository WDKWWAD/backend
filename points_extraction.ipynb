# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
from PIL import Image
im = Image.open("s.png")
im = im.convert('L')
im
# Out:
# <PIL.Image.Image image mode=L size=640x512 at 0x7F9844BCCE10>

# %%
width, height = im.size
array_of_3d_positions = []
for x in range(width):
    for y in range(height):  
        position_3d = x, y, im.getpixel((x,y))
        array_of_3d_positions.append(position_3d)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

x = np.array([point[0] for point in array_of_3d_positions[]])
y = np.array([point[1] for point in array_of_3d_positions[])
z = np.array([point[2] for point in array_of_3d_positions[0]])

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
